# %% [markdown]
# <a href="https://colab.research.google.com/github/amtalhansari205-collab/Natural_language_prosseing_LAB/blob/main/nlpexp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string

# %%
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
text = "I Am Computer"

# %%
def aree():
  print("Name: areeb ansari","UIN:231A030")

# %%
aree()
import string
print(string.punctuation)
# Out:
# Name: areeb ansari UIN:231A030
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
aree()
# Step 1: Preprocessing
text_lower = text.lower()

print(text_lower)
# Out:
# Name: areeb ansari UIN:231A030
# i am computer

# %%
# Step 2: Tokenization
aree()
tokens = word_tokenize(text_lower)
# Out:
# Name: areeb ansari UIN:231A030

# %%
aree()
tokens = word_tokenize(text_lower)

print(tokens)
# Out:
# Name: areeb ansari UIN:231A030
# ['i', 'am', 'computer']

# %%
aree()
text_clean=[]
for word in tokens:
    if word not in string.punctuation:
        text_clean.append(word)
print(text_clean)
# Out:
# Name: areeb ansari UIN:231A030
# ['i', 'am', 'computer']

# %%
aree()
# Step 3: Identify roots (morpheme approximation using lemmatizer)
lemmatizer = WordNetLemmatizer()
lemmas = [lemmatizer.lemmatize(tok, pos='v') for tok in text_clean] # Lemmatize as verbs
lemmas
# Out:
# Name: areeb ansari UIN:231A030
# ['i', 'be', 'computer']

# %%
lemmatizer.lemmatize("computer",pos='n')
# Out:
# 'computer'

# %%
[(token, lemma) for token, lemma in zip(tokens, lemmas)]
# Out:
# [('i', 'i'), ('am', 'be'), ('computer', 'computer')]

# %%
# Step 4: Analyze tokens manually for derivational vs inflectional
morphological_info = {}
for token, lemma in zip(tokens, lemmas):
    if token != lemma:
        # This indicates some morphological change
        if token.endswith("ing"):
            analysis = "Inflectional: Present participle/continuous form of '{}'".format(lemma)
        elif token.endswith("er")or("ation"):
            analysis = "Derivational: '{}' + -er → person who does the action".format(lemma)
        else:
            analysis = "Inflectional or irregular form of '{}'".format(lemma)
    else:
        analysis = "Base/root form"

    morphological_info[token]=analysis

# %%
morphological_info
# Out:
# {'i': 'Base/root form',
#  'am': "Derivational: 'be' + -er → person who does the action",
#  'computer': 'Base/root form'}

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()

words = [
    ("playing", "v"),
    ("played", "v"),
    ("studies", "v"),
    ("running", "v"),
    ("better", "a"),
    ("cars", "n")
]

pos_map = {
    "n": wordnet.NOUN,
    "v": wordnet.VERB,
    "a": wordnet.ADJ,
    "r": wordnet.ADV
}
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
