# %% [markdown]
# <a href="https://colab.research.google.com/github/amtalhansari205-collab/Natural_language_prosseing_LAB/blob/main/NLP_exp_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.corpus import twitter_samples
import matplotlib.pyplot as plt
import random

# %%
#download twitter sample dataset
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import twitter_samples

# %%
#load the dataset
tweets = twitter_samples.strings()
type(tweets)
# Out:
# list

# %%
len(tweets)
# Out:
# 30000

# %%
import pandas as pd
all_tweets=pd.DataFrame(tweets,columns = ["Tweets"])
all_tweets.head()
# Out:
#                                               Tweets
# 0                                hopeless for tmr :(
# 1  Everything in the kids section of IKEA is so c...
# 2  @Hegelbon That heart sliding into the waste ba...
# 3  “@ketchBurning: I hate Japanese call him "bani...
# 4           Dang starting next week I have "work" :(

# %%
"len of first",len(tweets[0])
# Out:
# ('len of first', 19)

# %%
twitter_samples.fileids()
# Out:
# ['negative_tweets.json', 'positive_tweets.json', 'tweets.20150430-223406.json']

# %%
#select the set of pos and neg
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')

# %%
len(positive_tweets)
# Out:
# 5000

# %%
len(negative_tweets)
# Out:
# 5000

# %%
positive_tweets=pd.DataFrame(positive_tweets, columns=["Positive "])
positive_tweets['Sentiments']='positive'
positive_tweets.tail()
# Out:
#                                               Positive  Sentiments
# 4995  @chriswiggin3 Chris, that's great to hear :) D...   positive
# 4996  @RachelLiskeard Thanks for the shout-out :) It...   positive
# 4997            @side556 Hey!  :)  Long time no talk...   positive
# 4998  @staybubbly69 as Matt would say. WELCOME TO AD...   positive
# 4999  @DanielOConnel18 you could say he will have eg...   positive

# %%
negative_tweets=pd.DataFrame(negative_tweets, columns=['Negative Tweets'])
negative_tweets['Sentiments']='Negative'
negative_tweets.tail()
# Out:
#                                         Negative Tweets Sentiments
# 4995               I wanna change my avi but uSanele :(   Negative
# 4996                         MY PUPPY BROKE HER FOOT :(   Negative
# 4997           where's all the jaebum baby pictures :((   Negative
# 4998  But but Mr Ahmad Maslan cooks too :( https://t...   Negative
# 4999  @eawoman As a Hull supporter I am expecting a ...   Negative

# %%
tweets=pd.concat([positive_tweets,negative_tweets],ignore_index= False)
tweets=tweets.sample(frac=1).reset_index(drop=True)
tweets
# Out:
#                                               Positive  Sentiments  \
# 0                                                   NaN   Negative
# 1                                                   NaN   Negative
# 2                                                   NaN   Negative
# 3                                                   NaN   Negative
# 4     goodnight I love everyone but hate myself beca...   positive
# ...                                                 ...        ...
# 9995  #FollowFriday @murtishaw @aqui_fr @FRTechStart...   positive
# 9996  @BrandonHerrigan Welcome :), when's your next ...   positive
# 9997  @mgallizzi it was a great read Matthew! Really...   positive
# 9998  @Insane_chorri don't worry, aapke benchmarks k...   positive
# 9999  @BhaktisBanter this lovely black &amp; red Max...   positive
#
#                                         Negative Tweets
# 0                              Take me back to Dubai :(
# ...

# %%
tweets[tweets['Sentiments']=='positive'].value_counts().sum()
tweets[tweets['Sentiments']=='Negative'].value_counts().sum()
# Out:
# np.int64(0)
